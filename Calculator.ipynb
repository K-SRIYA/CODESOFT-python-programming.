# %% [markdown]
# <a href="https://colab.research.google.com/github/K-SRIYA/CODESOFT-python-programming./blob/main/Calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output

# List to store history of calculations
history = []

# Function to perform calculation
def calculate(b):
    clear_output()
    display(ui)  # Re-display the UI elements after clearing the output

    try:
        num1 = float(num1_input.value)
        num2 = float(num2_input.value)
        operation = operation_dropdown.value

        if operation == 'Add':
            result = num1 + num2
        elif operation == 'Subtract':
            result = num1 - num2
        elif operation == 'Multiply':
            result = num1 * num2
        elif operation == 'Divide':
            if num2 != 0:
                result = num1 / num2
            else:
                result = 'Error: Division by zero'
        else:
            result = 'Invalid operation'

        # Update the result label
        result_label.value = f"Result: {result}"

        # Add the calculation to history
        history.append(f"{num1} {operation} {num2} = {result}")

        # Update the history label
        history_textarea.value = "\n".join(history)

    except ValueError:
        result_label.value = "Error: Invalid input"

# Creating UI elements
num1_input = widgets.Text(description="Number 1:")
num2_input = widgets.Text(description="Number 2:")
operation_dropdown = widgets.Dropdown(
    options=['Add', 'Subtract', 'Multiply', 'Divide'],
    description='Operation:'
)
calculate_button = widgets.Button(description="Calculate")
result_label = widgets.Label(value="Result:")
history_textarea = widgets.Textarea(
    value="",
    placeholder="Calculation history will be displayed here.",
    description="History:",
    disabled=True
)

# Setting up button click event handler
calculate_button.on_click(calculate)

# Displaying the UI
ui = widgets.VBox([num1_input, num2_input, operation_dropdown, calculate_button, result_label, history_textarea])
display(ui)
